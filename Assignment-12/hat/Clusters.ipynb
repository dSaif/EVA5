# %%
import requests
import json
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import seaborn as sns
import os
import numpy as np
sns.set()
plt.style.use("dark_background")

# %%
# !git clone https://github.com/dSaif/EVA5
# Out:
# Cloning into 'EVA5'...
# remote: Enumerating objects: 147, done.
# remote: Counting objects: 100% (147/147), done.
# remote: Compressing objects: 100% (139/139), done.
# remote: Total 147 (delta 22), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (147/147), 17.63 MiB | 18.50 MiB/s, done.
# Resolving deltas: 100% (22/22), done.

# %%
JSONFile = open('EVA5/Assignment-12/hat/annotations.json')
data = json.loads(JSONFile.read())

# %%
BASE_DIR = 'EVA5/Assignment-12/hat'

# %%
print(json.dumps(data["image-10.jpg42361"], indent=2))
# Out:
# {
#   "filename": "image-10.jpg",
#   "size": 42361,
#   "regions": [
#     {
#       "shape_attributes": {
#         "name": "rect",
#         "x": 32,
#         "y": 107,
#         "width": 79,
#         "height": 61
#       },
#       "region_attributes": {
#         "type": "hardhat",
#         "image_quality": {
#           "good": true,
#           "frontal": true,
#           "good_illumination": true
#         }
#       }
#     },
#     {
#       "shape_attributes": {
#         "name": "rect",
#         "x": 226,
#         "y": 158,
#         "width": 43,
#         "height": 32
#       },
#       "region_attributes": {
#         "type": "hardhat",
#         "image_quality": {
#           "good": true,
#           "frontal": true,
#           "good_illumination": true
#         }
#       }
#     },
#     {
#       "shape_attributes": {
#         "name": "rect",
#         "x": 283,
#         "y": 160,
#         "width": 36,
#         "height": 24
#       },
#       "region_attributes": {
#         "type": "hardhat",
#         "image_quality": {
#           "good": true,
#           "frontal": true,
#           "good_illumination": true
#         }
#       }
#     },
#     {
#       "shape_attributes": {
#         "name": "rect",
#         "x": 499,
#         "y": 152,
#         "width": 42,
#         "height": 29
#       },
#       "region_attributes": {
#         "type": "hardhat",
#         "image_quality": {
#           "good": true,
#           "frontal": true,
#           "good_illumination": true
#         }
#       }
#     },
#     {
#       "shape_attributes": {
#         "name": "rect",
#         "x": 544,
#         "y": 116,
#         "width": 68,
#         "height": 41
#       },
#       "region_attributes": {
#         "type": "hardhat",
#         "image_quality": {
#           "good": true,
#           "frontal": true,
#           "good_illumination": true
#         }
#       }
#     },
#     {
#       "shape_attributes": {
#         "name": "rect",
#         "x": 296,
#         "y": 389,
#         "width": 19,
#         "height": 22
#       },
#       "region_attributes": {
#         "type": "boots",
#         "image_quality": {
#           "good": true,
#           "frontal": true,
#           "good_illumination": true
#         }
#       }
#     },
#     {
#       "shape_attributes": {
#         "name": "rect",
#         "x": 316,
#         "y": 374,
#         "width": 19,
#         "height": 31
#       },
#       "region_attributes": {
#         "type": "boots",
#         "image_quality": {
#           "good": true,
#           "frontal": true,
#           "good_illumination": true
#         }
#       }
#     },
#     {
#       "shape_attributes": {
#         "name": "rect",
#         "x": 50,
#         "y": 162,
#         "width": 44,
#         "height": 38
#       },
#       "region_attributes": {
#         "type": "mask",
#         "image_quality": {
#           "good": true,
#           "frontal": true,
#           "good_illumination": true
#         }
#       }
#     },
#     {
#       "shape_attributes": {
#         "name": "rect",
#         "x": 232,
#         "y": 193,
#         "width": 29,
#         "height": 17
#       },
#       "region_attributes": {
#         "type": "mask",
#         "image_quality": {
#           "good": true,
#           "frontal": true,
#           "good_illumination": true
#         }
#       }
#     },
#     {
#       "shape_attributes": {
#         "name": "rect",
#         "x": 289,
#         "y": 186,
#         "width": 24,
#         "height": 18
#       },
#       "region_attributes": {
#         "type": "mask",
#         "image_quality": {
#           "good": true,
#           "frontal": true,
#           "good_illumination": true
#         }
#       }
#     },
#     {
#       "shape_attributes": {
#         "name": "rect",
#         "x": 508,
#         "y": 190,
#         "width": 25,
#         "height": 14
#       },
#       "region_attributes": {
#         "type": "mask",
#         "image_quality": {
#           "good": true,
#           "frontal": true,
#           "good_illumination": true
#         }
#       }
#     },
#     {
#       "shape_attributes": {
#         "name": "rect",
#         "x": 564,
#         "y": 161,
#         "width": 41,
#         "height": 32
#       },
#       "region_attributes": {
#         "type": "mask",
#         "image_quality": {
#           "good": true,
#           "frontal": true,
#           "good_illumination": true
#         }
#       }
#     },
#     {
#       "shape_attributes": {
#         "name": "rect",
#         "x": 55,
#         "y": 178,
#         "width": 128,
#         "height": 195
#       },
#       "region_attributes": {
#         "type": "vest",
#         "image_quality": {
#           "good": true,
#           "frontal": true,
#           "good_illumination": true
#         }
#       }
#     },
#     {
#       "shape_attributes": {
#         "name": "rect",
#         "x": 215,
#         "y": 208,
#         "width": 78,
#         "height": 110
#       },
#       "region_attributes": {
#         "type": "vest",
#         "image_quality": {
#           "good": true,
#           "frontal": true,
#           "good_illumination": true
#         }
#       }
#     },
#     {
#       "shape_attributes": {
#         "name": "rect",
#         "x": 275,
#         "y": 198,
#         "width": 67,
#         "height": 93
#       },
#       "region_attributes": {
#         "type": "vest",
#         "image_quality": {
#           "good": true,
#           "frontal": true,
#           "good_illumination": true
#         }
#       }
#     },
#     {
#       "shape_attributes": {
#         "name": "rect",
#         "x": 512,
#         "y": 191,
#         "width": 121,
#         "height": 171
#       },
#       "region_attributes": {
#         "type": "vest",
#         "image_quality": {
#           "good": true,
#           "frontal": true,
#           "good_illumination": true
#         }
#       }
#     },
#     {
#       "shape_attributes": {
#         "name": "rect",
#         "x": 477,
#         "y": 198,
#         "width": 41,
#         "height": 109
#       },
#       "region_attributes": {
#         "type": "vest",
#         "image_quality": {
#           "good": true,
#           "frontal": true,
#           "good_illumination": true
#         }
#       }
#     }
#   ],
#   "file_attributes": {
#     "caption": "",
#     "public_domain": "no",
#     "image_url": ""
#   }
# }

# %%
Image.open(os.path.join(BASE_DIR, "images", data["image-10.jpg42361"]["filename"]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x7FD1EFD8AD50>

# %%
def get_bbox(img_annot):
    bboxes = []
    for bbox in img_annot["regions"]:
        shape_attrs = bbox["shape_attributes"]
        x = shape_attrs["x"]
        y = shape_attrs["y"]
        width = shape_attrs["width"]
        height = shape_attrs["height"]

        bboxes.append((x, y, width, height))

    return bboxes

# %%
im = np.array(Image.open(os.path.join(BASE_DIR, "images", data["image-10.jpg42361"]["filename"])))
bboxes = get_bbox(data["image-10.jpg42361"])

# Create figure and axes
fig,ax = plt.subplots(1, figsize=(15,15))

# Display the image
ax.imshow(im)

for bbox in bboxes:
    x, y, width, height = bbox
    # Create a Rectangle patch
    rect = patches.Rectangle((x,y),width,height,linewidth=3,edgecolor='r',facecolor='none')

    # Add the patch to the Axes
    ax.add_patch(rect)
plt.axis('off')
plt.show()

# %%
def get_bboxratio(img_annot):
    ratios = []
    img_width, img_height = Image.open(os.path.join(BASE_DIR, "images", img_annot["filename"])).size
    for bbox in get_bbox(img_annot):
        x, y, width, height = bbox
        ratios.append([width/img_width, height/img_height])
    return ratios

# %%
# bounding box ratio - bbox_width/img_width and bbox_height/img_height
bbratio = []
for img_annot in data.values():
    bbratio.extend(get_bboxratio(img_annot))

# %%
bbratio = np.array(bbratio)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
plt.scatter(bbratio[:,0], bbratio[:,1], cmap="tab10")
plt.xlabel('width')
plt.ylabel('height')
plt.title('BB_RATIO')
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
for c in range(1, 15):
    kmeans = KMeans(n_clusters=c, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(bbratio)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 15), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters=4, init='k-means++', max_iter=300, n_init=10, random_state=0)
pred_y = kmeans.fit_predict(bbratio)
plt.figure(figsize=(10,8))
plt.scatter(bbratio[:,0], bbratio[:,1], c=pred_y, cmap="tab10", s=100)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, alpha=.7)
plt.title('Clustering of bbox ratios')
plt.show()

# %%
json_formatted = json.dumps(data, indent=2)
print(json_formatted)
# Out:
# {
#   "image-1.jpg123053": {
#     "filename": "image-1.jpg",
#     "size": 123053,
#     "regions": [
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 249,
#           "y": 194,
#           "width": 58,
#           "height": 41
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 512,
#           "y": 143,
#           "width": 60,
#           "height": 45
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 640,
#           "y": 130,
#           "width": 57,
#           "height": 41
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 843,
#           "y": 182,
#           "width": 69,
#           "height": 44
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 509,
#           "y": 404,
#           "width": 67,
#           "height": 51
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 256,
#           "y": 237,
#           "width": 36,
#           "height": 28
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 521,
#           "y": 184,
#           "width": 42,
#           "height": 29
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 649,
#           "y": 173,
#           "width": 39,
#           "height": 34
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 513,
#           "y": 452,
#           "width": 27,
#           "height": 27
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 853,
#           "y": 227,
#           "width": 35,
#           "height": 33
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 231,
#           "y": 556,
#           "width": 59,
#           "height": 32
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 797,
#           "y": 512,
#           "width": 72,
#           "height": 34
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 623,
#           "y": 456,
#           "width": 35,
#           "height": 36
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 456,
#           "y": 304,
#           "width": 43,
#           "height": 54
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 269,
#           "y": 564,
#           "width": 47,
#           "height": 40
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 236,
#           "y": 263,
#           "width": 101,
#           "height": 146
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 524,
#           "y": 198,
#           "width": 106,
#           "height": 140
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 626,
#           "y": 188,
#           "width": 114,
#           "height": 153
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 860,
#           "y": 243,
#           "width": 118,
#           "height": 158
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 512,
#           "y": 471,
#           "width": 99,
#           "height": 136
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       }
#     ],
#     "file_attributes": {
#       "caption": "",
#       "public_domain": "no",
#       "image_url": ""
#     }
#   },
#   "image-2.jpg109876": {
#     "filename": "image-2.jpg",
#     "size": 109876,
#     "regions": [
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 96,
#           "y": 0,
#           "width": 95,
#           "height": 66
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 340,
#           "y": 39,
#           "width": 73,
#           "height": 60
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 164,
#           "y": 52,
#           "width": 65,
#           "height": 45
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 111,
#           "y": 46,
#           "width": 56,
#           "height": 63
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 172,
#           "y": 98,
#           "width": 45,
#           "height": 42
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 351,
#           "y": 94,
#           "width": 53,
#           "height": 42
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 0,
#           "y": 76,
#           "width": 129,
#           "height": 248
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 127,
#           "y": 124,
#           "width": 93,
#           "height": 174
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 337,
#           "y": 112,
#           "width": 141,
#           "height": 200
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       }
#     ],
#     "file_attributes": {
#       "caption": "",
#       "public_domain": "no",
#       "image_url": ""
#     }
#   },
#   "image-3.jpg81057": {
#     "filename": "image-3.jpg",
#     "size": 81057,
#     "regions": [
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 79,
#           "y": 214,
#           "width": 182,
#           "height": 203
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 145,
#           "y": 80,
#           "width": 95,
#           "height": 74
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 154,
#           "y": 160,
#           "width": 69,
#           "height": 52
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       }
#     ],
#     "file_attributes": {
#       "caption": "",
#       "public_domain": "no",
#       "image_url": ""
#     }
#   },
#   "image-4.jpg55843": {
#     "filename": "image-4.jpg",
#     "size": 55843,
#     "regions": [
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 240,
#           "y": 179,
#           "width": 108,
#           "height": 78
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 224,
#           "y": 72,
#           "width": 156,
#           "height": 151
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 160,
#           "y": 269,
#           "width": 278,
#           "height": 263
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       }
#     ],
#     "file_attributes": {
#       "caption": "",
#       "public_domain": "no",
#       "image_url": ""
#     }
#   },
#   "image-5.jpg74310": {
#     "filename": "image-5.jpg",
#     "size": 74310,
#     "regions": [
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 131,
#           "y": 185,
#           "width": 156,
#           "height": 202
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 376,
#           "y": 179,
#           "width": 154,
#           "height": 235
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 167,
#           "y": 76,
#           "width": 96,
#           "height": 61
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 403,
#           "y": 44,
#           "width": 114,
#           "height": 68
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 204,
#           "y": 137,
#           "width": 43,
#           "height": 43
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 409,
#           "y": 116,
#           "width": 35,
#           "height": 54
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       }
#     ],
#     "file_attributes": {
#       "caption": "",
#       "public_domain": "no",
#       "image_url": ""
#     }
#   },
#   "image-6.jpg62158": {
#     "filename": "image-6.jpg",
#     "size": 62158,
#     "regions": [
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 221,
#           "y": 280,
#           "width": 32,
#           "height": 25
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 301,
#           "y": 292,
#           "width": 28,
#           "height": 21
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 315,
#           "y": 231,
#           "width": 140,
#           "height": 114
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 518,
#           "y": 297,
#           "width": 28,
#           "height": 19
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 215,
#           "y": 245,
#           "width": 44,
#           "height": 28
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 509,
#           "y": 260,
#           "width": 44,
#           "height": 30
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 272,
#           "y": 72,
#           "width": 213,
#           "height": 156
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 192,
#           "y": 306,
#           "width": 78,
#           "height": 122
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 257,
#           "y": 347,
#           "width": 336,
#           "height": 202
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 575,
#           "y": 215,
#           "width": 50,
#           "height": 31
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 583,
#           "y": 255,
#           "width": 35,
#           "height": 24
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       }
#     ],
#     "file_attributes": {
#       "caption": "",
#       "public_domain": "no",
#       "image_url": ""
#     }
#   },
#   "image-7.jpg202261": {
#     "filename": "image-7.jpg",
#     "size": 202261,
#     "regions": [
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 365,
#           "y": 100,
#           "width": 40,
#           "height": 28
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 357,
#           "y": 40,
#           "width": 66,
#           "height": 61
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 327,
#           "y": 401,
#           "width": 32,
#           "height": 97
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 355,
#           "y": 413,
#           "width": 42,
#           "height": 86
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       }
#     ],
#     "file_attributes": {
#       "caption": "",
#       "public_domain": "no",
#       "image_url": ""
#     }
#   },
#   "image-8.jpg201064": {
#     "filename": "image-8.jpg",
#     "size": 201064,
#     "regions": [
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 779,
#           "y": 125,
#           "width": 195,
#           "height": 165
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 549,
#           "y": 380,
#           "width": 450,
#           "height": 586
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 781,
#           "y": 296,
#           "width": 119,
#           "height": 110
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       }
#     ],
#     "file_attributes": {
#       "caption": "",
#       "public_domain": "no",
#       "image_url": ""
#     }
#   },
#   "image-9.jpg7447": {
#     "filename": "image-9.jpg",
#     "size": 7447,
#     "regions": [
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 73,
#           "y": 31,
#           "width": 29,
#           "height": 23
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 70,
#           "y": 7,
#           "width": 37,
#           "height": 25
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 49,
#           "y": 219,
#           "width": 42,
#           "height": 44
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 93,
#           "y": 222,
#           "width": 44,
#           "height": 36
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       }
#     ],
#     "file_attributes": {
#       "caption": "",
#       "public_domain": "no",
#       "image_url": ""
#     }
#   },
#   "image-10.jpg42361": {
#     "filename": "image-10.jpg",
#     "size": 42361,
#     "regions": [
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 32,
#           "y": 107,
#           "width": 79,
#           "height": 61
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 226,
#           "y": 158,
#           "width": 43,
#           "height": 32
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 283,
#           "y": 160,
#           "width": 36,
#           "height": 24
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 499,
#           "y": 152,
#           "width": 42,
#           "height": 29
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 544,
#           "y": 116,
#           "width": 68,
#           "height": 41
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 296,
#           "y": 389,
#           "width": 19,
#           "height": 22
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 316,
#           "y": 374,
#           "width": 19,
#           "height": 31
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 50,
#           "y": 162,
#           "width": 44,
#           "height": 38
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 232,
#           "y": 193,
#           "width": 29,
#           "height": 17
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 289,
#           "y": 186,
#           "width": 24,
#           "height": 18
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 508,
#           "y": 190,
#           "width": 25,
#           "height": 14
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 564,
#           "y": 161,
#           "width": 41,
#           "height": 32
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 55,
#           "y": 178,
#           "width": 128,
#           "height": 195
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 215,
#           "y": 208,
#           "width": 78,
#           "height": 110
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 275,
#           "y": 198,
#           "width": 67,
#           "height": 93
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 512,
#           "y": 191,
#           "width": 121,
#           "height": 171
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 477,
#           "y": 198,
#           "width": 41,
#           "height": 109
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       }
#     ],
#     "file_attributes": {
#       "caption": "",
#       "public_domain": "no",
#       "image_url": ""
#     }
#   },
#   "image-11.jpg36538": {
#     "filename": "image-11.jpg",
#     "size": 36538,
#     "regions": [
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 143,
#           "y": 43,
#           "width": 42,
#           "height": 31
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 344,
#           "y": 74,
#           "width": 54,
#           "height": 32
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 124,
#           "y": 95,
#           "width": 82,
#           "height": 124
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 314,
#           "y": 128,
#           "width": 109,
#           "height": 143
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 368,
#           "y": 110,
#           "width": 24,
#           "height": 24
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 134,
#           "y": 358,
#           "width": 32,
#           "height": 25
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 166,
#           "y": 356,
#           "width": 31,
#           "height": 28
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 341,
#           "y": 403,
#           "width": 32,
#           "height": 16
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 398,
#           "y": 403,
#           "width": 55,
#           "height": 17
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       }
#     ],
#     "file_attributes": {
#       "caption": "",
#       "public_domain": "no",
#       "image_url": ""
#     }
#   },
#   "image-12.jpg160929": {
#     "filename": "image-12.jpg",
#     "size": 160929,
#     "regions": [
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 119,
#           "y": 54,
#           "width": 28,
#           "height": 17
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 189,
#           "y": 458,
#           "width": 43,
#           "height": 29
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 378,
#           "y": 191,
#           "width": 85,
#           "height": 66
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 776,
#           "y": 305,
#           "width": 49,
#           "height": 38
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 156,
#           "y": 507,
#           "width": 100,
#           "height": 125
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 354,
#           "y": 306,
#           "width": 154,
#           "height": 201
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 743,
#           "y": 370,
#           "width": 98,
#           "height": 147
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 102,
#           "y": 86,
#           "width": 68,
#           "height": 89
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 195,
#           "y": 492,
#           "width": 28,
#           "height": 24
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 422,
#           "y": 257,
#           "width": 44,
#           "height": 42
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 781,
#           "y": 349,
#           "width": 36,
#           "height": 26
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 124,
#           "y": 74,
#           "width": 21,
#           "height": 16
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 110,
#           "y": 253,
#           "width": 33,
#           "height": 25
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 159,
#           "y": 248,
#           "width": 23,
#           "height": 28
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 136,
#           "y": 729,
#           "width": 51,
#           "height": 30
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 190,
#           "y": 754,
#           "width": 34,
#           "height": 32
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 361,
#           "y": 713,
#           "width": 63,
#           "height": 72
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 750,
#           "y": 669,
#           "width": 29,
#           "height": 54
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 785,
#           "y": 646,
#           "width": 44,
#           "height": 39
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       }
#     ],
#     "file_attributes": {
#       "caption": "",
#       "public_domain": "no",
#       "image_url": ""
#     }
#   },
#   "image-13.jpg176275": {
#     "filename": "image-13.jpg",
#     "size": 176275,
#     "regions": [
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 522,
#           "y": 303,
#           "width": 71,
#           "height": 70
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 456,
#           "y": 348,
#           "width": 54,
#           "height": 39
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 634,
#           "y": 414,
#           "width": 49,
#           "height": 68
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 621,
#           "y": 255,
#           "width": 94,
#           "height": 82
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 613,
#           "y": 401,
#           "width": 32,
#           "height": 21
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 674,
#           "y": 431,
#           "width": 41,
#           "height": 77
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 551,
#           "y": 365,
#           "width": 23,
#           "height": 22
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 649,
#           "y": 310,
#           "width": 34,
#           "height": 44
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 616,
#           "y": 430,
#           "width": 18,
#           "height": 16
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 406,
#           "y": 731,
#           "width": 58,
#           "height": 43
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 565,
#           "y": 717,
#           "width": 108,
#           "height": 43
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 760,
#           "y": 721,
#           "width": 93,
#           "height": 64
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 657,
#           "y": 733,
#           "width": 118,
#           "height": 62
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 684,
#           "y": 301,
#           "width": 193,
#           "height": 202
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
# ...
#           "width": 276,
#           "height": 299
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       }
#     ],
#     "file_attributes": {
#       "caption": "",
#       "public_domain": "no",
#       "image_url": ""
#     }
#   },
#   "image-51.jpg29625": {
#     "filename": "image-51.jpg",
#     "size": 29625,
#     "regions": [
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 368,
#           "y": 19,
#           "width": 147,
#           "height": 102
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 384,
#           "y": 125,
#           "width": 109,
#           "height": 98
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 319,
#           "y": 221,
#           "width": 263,
#           "height": 311
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       }
#     ],
#     "file_attributes": {
#       "caption": "",
#       "public_domain": "no",
#       "image_url": ""
#     }
#   },
#   "image-52.jpg110438": {
#     "filename": "image-52.jpg",
#     "size": 110438,
#     "regions": [
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 583,
#           "y": 26,
#           "width": 296,
#           "height": 185
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 623,
#           "y": 254,
#           "width": 236,
#           "height": 136
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 514,
#           "y": 384,
#           "width": 459,
#           "height": 682
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       }
#     ],
#     "file_attributes": {
#       "caption": "",
#       "public_domain": "no",
#       "image_url": ""
#     }
#   },
#   "image-53.jpg90526": {
#     "filename": "image-53.jpg",
#     "size": 90526,
#     "regions": [
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 492,
#           "y": 15,
#           "width": 72,
#           "height": 55
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 501,
#           "y": 60,
#           "width": 63,
#           "height": 53
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 448,
#           "y": 76,
#           "width": 205,
#           "height": 266
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 818,
#           "y": 30,
#           "width": 60,
#           "height": 43
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 826,
#           "y": 68,
#           "width": 50,
#           "height": 39
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 778,
#           "y": 84,
#           "width": 169,
#           "height": 221
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 511,
#           "y": 493,
#           "width": 49,
#           "height": 52
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 555,
#           "y": 460,
#           "width": 50,
#           "height": 77
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 829,
#           "y": 398,
#           "width": 42,
#           "height": 54
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 882,
#           "y": 401,
#           "width": 64,
#           "height": 51
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       }
#     ],
#     "file_attributes": {
#       "caption": "",
#       "public_domain": "no",
#       "image_url": ""
#     }
#   },
#   "image-54.jpg62192": {
#     "filename": "image-54.jpg",
#     "size": 62192,
#     "regions": [
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 119,
#           "y": 106,
#           "width": 88,
#           "height": 72
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 129,
#           "y": 161,
#           "width": 71,
#           "height": 62
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 268,
#           "y": 83,
#           "width": 102,
#           "height": 72
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 291,
#           "y": 136,
#           "width": 68,
#           "height": 65
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 307,
#           "y": 171,
#           "width": 145,
#           "height": 201
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       }
#     ],
#     "file_attributes": {
#       "caption": "",
#       "public_domain": "no",
#       "image_url": ""
#     }
#   },
#   "image-55.jpg59581": {
#     "filename": "image-55.jpg",
#     "size": 59581,
#     "regions": [
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 182,
#           "y": 12,
#           "width": 44,
#           "height": 27
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 271,
#           "y": 13,
#           "width": 42,
#           "height": 30
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 139,
#           "y": 328,
#           "width": 27,
#           "height": 30
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 185,
#           "y": 331,
#           "width": 48,
#           "height": 25
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 257,
#           "y": 330,
#           "width": 34,
#           "height": 27
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 319,
#           "y": 331,
#           "width": 28,
#           "height": 25
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       }
#     ],
#     "file_attributes": {
#       "caption": "",
#       "public_domain": "no",
#       "image_url": ""
#     }
#   },
#   "image-56.jpg58135": {
#     "filename": "image-56.jpg",
#     "size": 58135,
#     "regions": [
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 182,
#           "y": 51,
#           "width": 112,
#           "height": 72
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 201,
#           "y": 120,
#           "width": 75,
#           "height": 61
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 139,
#           "y": 188,
#           "width": 179,
#           "height": 229
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 503,
#           "y": 122,
#           "width": 72,
#           "height": 49
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 513,
#           "y": 165,
#           "width": 57,
#           "height": 54
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 457,
#           "y": 189,
#           "width": 139,
#           "height": 227
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       }
#     ],
#     "file_attributes": {
#       "caption": "",
#       "public_domain": "no",
#       "image_url": ""
#     }
#   },
#   "image-57.jpg45878": {
#     "filename": "image-57.jpg",
#     "size": 45878,
#     "regions": [
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 218,
#           "y": 32,
#           "width": 57,
#           "height": 39
#         },
#         "region_attributes": {
#           "type": "hardhat",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 223,
#           "y": 73,
#           "width": 47,
#           "height": 33
#         },
#         "region_attributes": {
#           "type": "mask",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 189,
#           "y": 111,
#           "width": 115,
#           "height": 152
#         },
#         "region_attributes": {
#           "type": "vest",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 182,
#           "y": 416,
#           "width": 41,
#           "height": 43
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       },
#       {
#         "shape_attributes": {
#           "name": "rect",
#           "x": 263,
#           "y": 407,
#           "width": 29,
#           "height": 56
#         },
#         "region_attributes": {
#           "type": "boots",
#           "image_quality": {
#             "good": true,
#             "frontal": true,
#             "good_illumination": true
#           }
#         }
#       }
#     ],
#     "file_attributes": {
#       "caption": "",
#       "public_domain": "no",
#       "image_url": ""
#     }
#   }
# }
